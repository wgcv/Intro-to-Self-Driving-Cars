# %%
# %%HTML
# <button id="launcher">Launch Car Simulator</button>
# <script src="setupLauncher.js"></script>
# Out:
# <button id="launcher">Launch Car Simulator</button>
# <script src="setupLauncher.js"></script>

# %%
from Car import Car
import time

def circle(car):
    car.steer(5)
    car.gas(1)
    
car = Car()

circle(car)
